# %%
import pandas as pd
import psycopg2

# %%
# Dados de conexão
user = "leiturabd_24072024"
password = "bbtSBIE5sr66qe9"
host = "72.14.201.237"  # IP remoto
port = "5432"
database = "drogariajb_esc"

# %%
try:
    # Estabelecendo a conexão
    connection = psycopg2.connect(
        user=user,
        password=password,
        host=host,
        port=port,
        database=database
    )
    print("Conexão bem-sucedida ao banco de dados!")

    # Fechando a conexão
    connection.close()
except Exception as e:
    print(f"Erro ao conectar ao banco de dados: {e}")
# Out:
# Erro ao conectar ao banco de dados: connection to server at "72.14.201.237", port 5432 failed: Connection timed out (0x0000274C/10060)
# 	Is the server running on that host and accepting TCP/IP connections?
